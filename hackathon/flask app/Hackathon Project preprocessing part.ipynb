# %% [markdown]
# # Sdsf Hackathon

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('my_file.csv')

# %% [markdown]
# # Data Preprocessing:

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#    Unnamed: 0     Device ID  Latitude  Longitude        UTC  TotalDistance  \
# 0         194  3.592071e+14  26.23398   82.07257  762107400       74637.86
# 1        2812  3.592071e+14  15.44799   74.41168  762107405      109469.44
# 2        6557  3.592071e+14  11.24877   77.53083  762107412       33886.21
# 3        7663  3.592071e+14  21.99830   78.87768  762107414       53102.26
# 4       12021  3.592071e+14  10.80459   78.71200  762107422       84239.37
#
#    EngineSpeed  VehicleSpeed  FuelLevel  AccPedalPosition     HRLFC  \
# 0          0.0          0.00       52.4               0.0  12704.93
# 1       1009.0         41.14       88.8              96.0  20240.82
# 2       1112.5         53.11       54.8              18.8   6039.37
# 3       1180.0         56.87       58.0              35.2   9002.99
# 4       1260.0         54.00       49.2              47.2  16870.80
#
#    EngineCoolantTemp
# 0                 64
# 1                 88
# 2                 86
# 3                 86
# 4                 85

# %%
df.tail()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885848 entries, 0 to 885847
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         885848 non-null  int64
#  1   Device ID          885848 non-null  float64
#  2   Latitude           885848 non-null  float64
#  3   Longitude          885848 non-null  float64
#  4   UTC                885848 non-null  int64
#  5   TotalDistance      885848 non-null  float64
#  6   EngineSpeed        885848 non-null  float64
#  7   VehicleSpeed       885848 non-null  float64
#  8   FuelLevel          885848 non-null  float64
#  9   AccPedalPosition   885848 non-null  float64
#  10  HRLFC              885848 non-null  float64
#  11  EngineCoolantTemp  885848 non-null  int64
# dtypes: float64(9), int64(3)
# memory usage: 81.1 MB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Device ID            0
# Latitude             0
# Longitude            0
# UTC                  0
# TotalDistance        0
# EngineSpeed          0
# VehicleSpeed         0
# FuelLevel            0
# AccPedalPosition     0
# HRLFC                0
# EngineCoolantTemp    0
# dtype: int64

# %%
# Check for duplicate rows
duplicate_rows = df.duplicated().sum()

# %%
duplicate_rows
# Out:
# 0

# %% [markdown]
# # EDA

# %%
df.describe()

# %%
# Compute correlation matrix
correlation_matrix = df.corr()

# Plot correlation heatmap
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
from pandas_profiling import ProfileReport
#profile = ProfileReport(df)
#profile.to_file("my_files_report.html")
# Out:
# C:\Users\deven\AppData\Local\Temp\ipykernel_17848\1514108026.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
